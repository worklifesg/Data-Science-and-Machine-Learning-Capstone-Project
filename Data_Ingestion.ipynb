# %%
#Importing the data file on 311 NYC system Department of Housing Preservation and Development 
import pandas as pd
file="D:\Python\edx\Capstone project\data_311_correct.csv"
df=pd.read_csv(file)

# %%
#Looking at the dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019843 entries, 0 to 6019842
# Data columns (total 16 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0              int64
#  1   Unique Key              int64
#  2   Created Date            object
#  3   Closed Date             object
#  4   Complaint Type          object
#  5   Location Type           object
#  6   Incident Zip            float64
#  7   Incident Address        object
#  8   Street Name             object
#  9   Address Type            object
#  10  City                    object
#  11  Status                  object
#  12  Resolution Description  object
#  13  Borough                 object
#  14  Latitude                float64
#  15  Longitude               float64
# dtypes: float64(3), int64(2), object(11)
# memory usage: 734.8+ MB

# %%
# Q1. The dataset contains complaints logged since what date?
df_asc=df.sort_values(by=['Created Date'])
df_asc.head()
# Out:
#         Unnamed: 0  Unique Key            Created Date  \
# 177182      177182    15634460  01/01/2010 02:31:13 PM
# 177179      177179    15634698  01/01/2010 02:39:02 PM
# 177186      177186    15633862  01/01/2010 04:18:46 PM
# 177188      177188    15633410  01/01/2010 04:59:23 PM
# 177180      177180    15634558  01/01/2010 05:00:01 AM
#
#                    Closed Date          Complaint Type Location Type  \
# 177182  01/02/2010 02:35:01 PM  HPD Literature Request           NaN
# 177179  01/04/2010 01:20:45 PM  HPD Literature Request           NaN
# 177186  01/04/2010 01:20:46 PM  HPD Literature Request           NaN
# 177188  01/02/2010 05:02:49 PM  HPD Literature Request           NaN
# 177180  01/04/2010 01:20:48 PM  HPD Literature Request           NaN
#
#         Incident Zip Incident Address Street Name Address Type City  Status  \
# 177182           NaN              NaN         NaN          NaN  NaN  Closed
# ...

# %%
# Q2. The dataset contains complaints logged till what date?
df.head()
# Out:
#    Unnamed: 0  Unique Key            Created Date Closed Date  \
# 0           0    45531130  02/02/2020 06:09:17 AM         NaN
# 1           1    45529784  02/02/2020 02:15:24 PM         NaN
# 2           2    45527528  02/02/2020 02:27:41 AM         NaN
# 3           3    45530329  02/02/2020 12:13:18 PM         NaN
# 4           4    45528814  02/02/2020 01:59:44 PM         NaN
#
#          Complaint Type         Location Type  Incident Zip  \
# 0        HEAT/HOT WATER  RESIDENTIAL BUILDING       10019.0
# 1  UNSANITARY CONDITION  RESIDENTIAL BUILDING       11204.0
# 2        HEAT/HOT WATER  RESIDENTIAL BUILDING       11372.0
# 3        HEAT/HOT WATER  RESIDENTIAL BUILDING       10458.0
# 4             APPLIANCE  RESIDENTIAL BUILDING       11209.0
#
#           Incident Address         Street Name Address Type             City  \
# 0     426 WEST   52 STREET    WEST   52 STREET      ADDRESS         NEW YORK
# ...

# %%
# Q3. How many incidents have a missing Incident Address?
df_missing_info=df.isnull().sum()
df_missing_info
# Out:
# Unnamed: 0                     0
# Unique Key                     0
# Created Date                   0
# Closed Date               126657
# Complaint Type                 0
# Location Type              52824
# Incident Zip               80697
# Incident Address           52825
# Street Name                52825
# Address Type               84765
# City                       80274
# Status                         0
# Resolution Description      7826
# Borough                        0
# Latitude                   80671
# Longitude                  80671
# dtype: int64

# %%
# Bronx PLUTO dataset
file_Bronx="D:\Python\edx\Capstone project\BX_18v1.csv"
df_br=pd.read_csv(file_Bronx)
df_br.head()
# Out:
# C:\Users\Home\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (19,20,22,23,64,65,80) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      BX   2260    1  201    19.0  1022.0         7.0      8.0  10454.0
# 1      BX   2260    4  201    19.0  1022.0         7.0      8.0  10454.0
# 2      BX   2260   10  201    19.0  1022.0         7.0      8.0  10454.0
# 3      BX   2260   17  201    19.0  1022.0         7.0      8.0  10454.0
# 4      BX   2260   18  201    19.0  1022.0         7.0      8.0  10454.0
#
#   FireComp  ...  ZMCode  Sanborn   TaxMap  EDesigNum  APPBBL APPDate  \
# 0     L029  ...     NaN  209S016  20901.0      E-143     0.0     NaN
# 1     L029  ...     NaN  209S016  20901.0      E-143     0.0     NaN
# ...

# %%
# Q4. How many valid ZIP Codes exist in the Bronx PLUTO dataset?
zip_code_bronx=df_br["ZipCode"].value_counts() # frequency of each zip code
len(zip_code_bronx) # to count the number of zip codes
# Out:
# 26

# %%
# Queens PLUTO dataset
file_Queens="D:\Python\edx\Capstone project\QN_18v1.csv"
df_Queens=pd.read_csv(file_Queens)
df_Queens.head()
# Out:
# C:\Users\Home\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (19,20,22,23,64,65,77) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Borough  Block  Lot   CD  CT2010  CB2010  SchoolDist  Council  ZipCode  \
# 0      QN      6    1  402     1.0     NaN        30.0     26.0  11101.0
# 1      QN      6    3  402     1.0  1015.0        30.0     26.0  11101.0
# 2      QN      6    8  402     1.0  1011.0        30.0     26.0  11101.0
# 3      QN      6   20  402     1.0     NaN        30.0     26.0  11101.0
# 4      QN      6   30  402     1.0     NaN        30.0     26.0  11101.0
#
#   FireComp  ...  ZMCode  Sanborn   TaxMap  EDesigNum        APPBBL  \
# 0     L115  ...       Y  401 011  40101.0        NaN  4.000060e+09
# 1     L115  ...     NaN  401 011  40101.0        NaN  0.000000e+00
# ...

# %%
# Q5. How many valid ZIP Codes exist in the Queens PLUTO dataset?
zip_code_queens=df_Queens["ZipCode"].value_counts() # frequency of each zip code
len(zip_code_queens) # to count the number of zip codes
# Out:
# 65
